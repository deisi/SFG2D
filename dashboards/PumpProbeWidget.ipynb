# %%
# %pylab notebook
import ipywidgets as wi
from IPython.display import display
# %load_ext autoreload
# %autoreload 2
import sfg2d
import sfg2d.widgets as mywidgets
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Victor Dashboard
#
# A dashboard to quickly view data.

# %% [markdown]
# ### Copy and Pase
#
# ```
# /home/malte/MeasurmentData/Dolly1/2016/10/20
# /home/malte/MeasurmentData/Viktor/2017/08/08
# /mnt/dolly1/malte/2017/03/01
# /mnt/viktor/deiseroth/data/2017/05/10
# ```

# %%
victor = mywidgets.PumpProbe()
victor()
w0, w1, w2 = victor.tabed_widgets
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /home/malte/.virtualenvs/sfg2d/lib/python3.5/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/malte/.virtualenvs/sfg2d/lib/python3.5/site-packages/numpy/core/_methods.py:125: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/malte/sfg2d/sfg2d/core.py:863: RuntimeWarning: divide by zero encountered in true_divide
#   bleach = pumped / unpumped
# /home/malte/sfg2d/sfg2d/core.py:863: RuntimeWarning: invalid value encountered in true_divide
#   bleach = pumped / unpumped
# /home/malte/sfg2d/sfg2d/core.py:874: RuntimeWarning: invalid value encountered in subtract
#   bleach -= zero_time
# [0]
# [0]
# [0]
# [0]
# [0]
# /home/malte/.virtualenvs/sfg2d/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# [0]
# [0]

# %%
w0.spw

# %%
w0.spectra('rawData')
# Out:
# array([], shape=(1, 1, 0, 1600), dtype=float64)

# %%
w0.data.pp_delays
# Out:
# array([0])

# %%
wi.Dropdown()
# Out:
# [autoreload of sfg2d.widgets failed: Traceback (most recent call last):
#   File "/home/malte/.local/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/malte/.local/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/home/malte/.virtualenvs/sfg2d/lib/python3.5/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/malte/.virtualenvs/sfg2d/lib/python3.5/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 626, in _exec
#   File "<frozen importlib._bootstrap_external>", line 661, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 767, in get_code
#   File "<frozen importlib._bootstrap_external>", line 727, in source_to_code
#   File "<frozen importlib._bootstrap>", line 222, in _call_with_frames_removed
#   File "/home/malte/sfg2d/sfg2d/widgets.py", line 1057
#     def _plot_bleach_abs(self, ax):
#       ^
# IndentationError: expected an indented block
# ]

# %%
np.__version__
# Out:
# '1.13.1'

# %%
np.isin?
