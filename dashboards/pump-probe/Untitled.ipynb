# %%
# %pylab notebook
import sfg2d
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ffile = 'C:/Users/deiseroth/MeasurmentData/sudipta/2016/09/30/04_kin_d2o_pr1_vis1_pu0_conv_t20m_ssp_fr1_hb1_wl676_gal1_chop1.dat'
sp = sfg2d.io.veronica.read_scan_stack(ffile)
sp0 = pd.read_csv(ffile, sep="\t", header=None, skiprows=1, skipfooter=1)
# Out:
# c:\users\deiseroth\sfg2d\sfg2d\io\veronica.py:119: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   **kwargs
# C:\Users\deiseroth\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()

# %%
dtype.
# Out:
# numpy.dtype

# %%
sp.med.plot()
# Out:
# <img src="data:image/png;base64,...">
