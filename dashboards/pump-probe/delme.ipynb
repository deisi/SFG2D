# %%
import numpy as np
from IPython.display import display
from bqplot import LinearScale, Axis, Lines, Figure, Toolbar, PanZoom
from ipywidgets import ToggleButtons

x_label = ""
y_label = ""
title = ""

x_sc = LinearScale()
y_sc = LinearScale()

line = Lines(scales={'x':x_sc, 'y':y_sc})

ax_x = Axis(scale=x_sc,
            label=x_label)
ax_y = Axis(scale=y_sc, 
            label=y_label, orientation='vertical')

def tb_update(new):
    if not tb0._panning:    
        return
    if tb.value == 'y':
        tb0._panzoom.scales={'y': [y_sc]}
    elif tb.value == 'x':
        tb0._panzoom.scales={'x': [x_sc]}
    else:
        tb0._panzoom.scales={'x': [x_sc], 'y': [y_sc]}

tb = ToggleButtons(options=['y', 'x', 'both'], value='both')
tb.observe(tb_update, "value")

fig = Figure(marks=[line], axes=[ax_x, ax_y], 
             title=title)

tb0 = Toolbar(figure=fig)

fig.marks[0].x = np.arange(10)
fig.marks[0].y = np.random.random(10)

display(fig, tb0, tb)

# %%
ax = fig.axes[0]
sx = fig.scale_x


fig.get_state(), sx.get_state(), ax.get_state()
sx.max
# Out:
# 1.0

# %%
tb0._panzoom.scales.
# Out:
# {'x': [<bqplot.scales.LinearScale at 0xaf93ac4c>],
#  'y': [<bqplot.scales.LinearScale at 0xb06759ac>]}

# %%
(1/640-1/794)*10**7
# Out:
# 3030.5415617128474

# %%
x_sc.min
# Out:
# 2.0458216859390705

# %%
from SFG2D.utils import winspec

# %%
# %pylab notebook

sp = winspec.read_spe('/home/malte/MeasurmentData/servive_lab/00_sp_gold_ppp_caf_lense.spe')

plot(sp["data"][0].T)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <img src="data:image/png;base64,...">

# %%
sp["data"][0][0]
# Out:
# array([ 617.,  616.,  614., ...,  605.,  604.,  603.])

# %%
import SFG2D.utils.read_spe as read_spe

sp =read_spe.read_spe('/home/malte/MeasurmentData/servive_lab/00_sp_gold_ppp_caf_lense.spe')
sp["data"]
# Out:
# [array([[ 617.,  616.,  614., ...,  605.,  604.,  603.]])]
